# %%
import cv2
import requests

# %% [markdown]
# #### HTTP get method request

# %%
api_endpoint = r"http://192.168.100.2:8080"

# %%
response = requests.get(api_endpoint)

# %%
response.text
# Out:
# 'Hello this v0.0.0.1....'

# %% [markdown]
# #### HTTP post method request

# %%
req_json = {
    "data" : "hello"
}
api_endpoint = r"http://192.168.100.2:8080/test"

# %%
response = requests.post(api_endpoint,json = req_json)
print(response.text)
# Out:
# <!doctype html>
# <html lang=en>
# <title>404 Not Found</title>
# <h1>Not Found</h1>
# <p>The requested URL was not found on the server. If you entered the URL manually please check your spelling and try again.</p>

# %% [markdown]
# ### HTTP image path request

# %%
import matplotlib.pyplot as plt

# %%
img_path = r"D:\test_1\test_car.PNG"

# %%
req_json = {
    "img_path" : img_path
}
api_endpoint = r"http://192.168.100.2:8080/predict_imgurl"
response = requests.post(api_endpoint,json = req_json)
print(response.text)
# Out:
# corolla

# %% [markdown]
# ### HTTP image  request

# %%
img= cv2.imread(img_path)
img= cv2.resize(img,(256,256))
print(img.shape)
plt.imshow(img)
# Out:
# (256, 256, 3)

# %%
img.shape
# Out:
# (256, 256, 3)

# %%
import base64
import numpy as np
retval, buffer = cv2.imencode('.jpg', img)
jpg_as_text = base64.b64encode(buffer)
jpg_original = base64.b64decode(jpg_as_text)
jpg_original
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x01\x00\x01\x00\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xfc\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x9ad\x00\xe0\x83\xf9SE\xca\x16\xdb\xb1\xba\xe3\x95\xa0\t(\xa6\xbc\x8a\x83\xa1?A\x9ao\xdaW\xfey\xbf\xfd\xf3@\x12QQ\xfd\xa5\x7f\xe7\x9b\xff\x00\xdf4\xef6<d0?J\x00u\x14\x8a\xc1\xbaR\xd0\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x14P\x01E\x07\x80j7\x9ba\x1b\x8f\xde8\x14\x01%\x15J\xfe\xf2\xea\xd6Q\xe5\xc4\x19Ll\xc0t\xc9\x18\xe3>\xf9\xfd)R\xf8G\x0f\xda\xae\xaeQQ\x89\xc0#\x18\xf6\xa0WE\xcaF`\xa3&\xb05?\x88\x9a\x16\x98\xa5\x1eti\x7f\x86?0\x0c\xfe&\xb0\xaf>)\\\xf9\xc0Ey`\x88\xe7\xe4\x0fp\x99\x1f^jy\x90]\x1d\xb8yX\xe5$P=\r+\xc9\x10\x8c\x96\x9dzs\xc8\xaf5\xbf\xf8\x81;\xdc\x15]^\xd9\xe4\xc0\xf9"\xbc@:}j\x18\xf5M~\xe6U\x92\xda\xf9f\x8c\xb02\xb2N\xa4 \xef\x9ey\xa5)\xa8\x8djzl3[\xef;nU\x8e=j_:/\xf9\xf8O\xccW\x95jZ\xd6\xbbn\xa5\xe0\x8eY\x95\x01f\xf2\x9b\x07\x00z\xd5K\x8f\x11\xeaq;#_J\x8c\x85\xd5\xd1\x89$awn\xfav\xc7^hSRW\x1d\x99\xeb\xe6X\xf1\xc4\xe8}\xb2*4i\xf3\xcc\x08\x9f\xeddW\x9a\xf9\xfa\x84\x08\xd7z\x87\x88c\xb3U]\xde\\\xf3\x80\xe0c<\x02r\xd8\x18<z\xd75s\xfbQ|\x1b\xd2n^\xcf\\\xf8\xaemf\x8d\xb64s\xdbL9\xf5\xfb\xbd*\xae\x82\xcc\xf7H\x8b\x92w\xb8>\x98\xa7\xd7\x81\xf8w\xf6\xd0\xf8%r\x8bq\xa6|\\\xb2\xb9K\xb0\x1a\xdd\r\x9c\xc4\xb0\xc7N\x9cu\xafC\xf0\xaf\xc6\xef\x0ex\x8e\xc5n\xa3\x9e=\x87?\xbd2\x85\xdc3\x8e\x14\xf3E\xd0Y\x9d\xcd\x15\x99\xa7\xf8\x86\xcfR1\x1b9U\xd2H\xcb\x07\x07\xd0\xe3\x91\xd4U\xb8o\x1ai\x19Qr\xa0\xfd\xef\x7fJkP\xb3,QH3\x8eE-\x02\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\x11\xba\x1a\x8aDY\n\x92~\xebf\x9dt\x01\xb7q\xbbnP\x8c\x8e\xd5\xe2\xff\x00\xb5\x07\xed\x17\x17\xec\xe3\xf0\xc8jPZ\xdaj^,\xd6\xaf\x97K\xf0O\x87\x1er\x1fY\xd4\xda=\xd1\xc2@\xf9\xb6*+M!^V(]\xf0qQ)X\x89K\x94\xa3\xfbI~\xd5\xb2\xf8\x1f\xc6\xfa7\xc0\x9f\x86\xdau\xb6\xab\xe2\xfdr_:\xe2\xde\xe3&\r\'LS\x89/\xae\xb6\x90D9\r\x18\xdb\x96\xde\xcb\xc69\xaf4\xf8\xfb\xfbGx\xa2\xd5d\xfb\x1f\x89\xa7\xb4\xc3\x1c\xc1\x03\x80\xb1\xff\x00\xb23\xe9\xfc\xeb\x0b\xc1\x9f\x0f% ...

# %%
jpg_as_np = np.frombuffer(jpg_original, dtype=np.uint8)
img = cv2.imdecode(jpg_as_np, flags=1)
plt.imshow(img)

# %%
test_str_img = jpg_as_text.decode('utf-8')
print(type(test_str_img))
# Out:
# <class 'str'>

# %%
req_json = {
    "img_data" : [jpg_as_text.decode()]
}
print(type(req_json))
# Out:
# <class 'dict'>

# %%
api_endpoint = r"http://192.168.100.2:8080/predict_img"
response = requests.post(api_endpoint,json = req_json)
print(response.text)


jpg_original = str.encode(test_str_img)
jpg_as_np = np.frombuffer(jpg_original, dtype=np.uint8)
img = cv2.imdecode(jpg_as_np, flags=1)
print(img)
# Out:
# <!doctype html>
# <html lang=en>
# <title>500 Internal Server Error</title>
# <h1>Internal Server Error</h1>
# <p>The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.</p>

# %%
# Out:
# None
