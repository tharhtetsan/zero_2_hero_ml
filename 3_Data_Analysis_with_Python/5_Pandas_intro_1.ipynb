# %%
#!pip install pandas
#!pip install openpyxl

# %%
import pandas as pd

# %%
file = "section_1.xlsx"
df = pd.read_excel(file)

# %%
test = df.head()
test
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
print("len(df) : ",len(df))
print("df.shape : ",df.shape)
print(df.to_string)
# Out:
# len(df) :  1952
# df.shape :  (1952, 25)
# <bound method DataFrame.to_string of       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# ...

# %%
test_json = {
    "col1" : ["thar","htet","san"],
    "col2":[1,2,3]
}

# %%
test_df = pd.DataFrame(test_json)
test_df.head()
# Out:
#    col1  col2
# 0  thar     1
# 1  htet     2
# 2   san     3

# %%
test_df.to_csv("test.csv")
print(pd.__version__)
# Out:
# 1.5.0

# %%
a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
print(myvar[0])
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# 1

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
print(myvar["day1"])
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
# 420

# %% [markdown]
# ### Data frame index call and change

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

data_df = pd.DataFrame(data)
print(data_df)
print(data_df["calories"])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# 0    420
# 1    380
# 2    390
# Name: calories, dtype: int64

# %%
cal0,dur0 = (data_df.loc[0])
print(cal0)
print(dur0)
# Out:
# 420
# 50

# %%
data1_df = pd.DataFrame(data,index = [2,4,6])
print(data1_df)
# Out:
#    calories  duration
# 2       420        50
# 4       380        40
# 6       390        45

# %%
cal0,dur0 = (data1_df.loc[6])
print(cal0)
print(dur0)
# Out:
# 390
# 45

# %%
test = (data1_df["calories"])
print(test)
data1_df.to_csv("test.csv")
# Out:
# 2    420
# 4    380
# 6    390
# Name: calories, dtype: int64

# %% [markdown]
# ### Change data frame max show

# %%
print(pd.options.display.max_rows) 
df
# Out:
# 60
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %%
pd.options.display.max_rows = 9999
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 1      20228  Not Specified      0.02      500.98          26.00            5
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# 5      24847         Medium      0.05        3.28           4.20           14
# 6      24848         Medium      0.05        3.58           1.63           14
# 7      18181       Critical      0.00        4.42           4.99           15
# 8      20925         Medium      0.01       35.94           6.66           15
# 9      26267           High      0.04        2.98           1.58           16
# 10     26268           High      0.05      115.99           2.50           16
# ...

# %% [markdown]
# ### JSON read/write

# %%
json_df = test
json_df.to_json("test.json")

# %%
json_readdf = pd.read_json("test.json")
print(type(json_readdf))
json_readdf.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
print(json_readdf.info())
print(json_readdf['Discount'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                5 non-null      int64
#  1   Order Priority        5 non-null      object
#  2   Discount              5 non-null      float64
#  3   Unit Price            5 non-null      float64
#  4   Shipping Cost         5 non-null      float64
#  5   Customer ID           5 non-null      int64
#  6   Customer Name         5 non-null      object
#  7   Ship Mode             5 non-null      object
#  8   Customer Segment      5 non-null      object
#  9   Product Category      5 non-null      object
#  10  Product Sub-Category  5 non-null      object
#  11  Product Container     5 non-null      object
#  12  Product Name          5 non-null      object
#  13  Product Base Margin   5 non-null      float64
#  14  Country               5 non-null      object
# ...

# %%
datatype  = json_readdf['Row ID'].info
print(datatype)
# Out:
# <bound method Series.info of 0    20847
# 1    20228
# 2    21776
# 3    24844
# 4    24846
# Name: Row ID, dtype: int64>

# %%
json_readdf
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %% [markdown]
# ### Replace Only For Specified Columns

# %%
df = pd.read_json("test.json")
df
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
# Replace NULL values in the "Order Priority"
result = df['Order Priority'].fillna('Medium',inplace = True)
df
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
x = df['Shipping Cost'].mean()
print("mean : ",x)
# Out:
# mean :  11.303999999999998

# %%
import numpy as np
array_s = df['Shipping Cost']
print(np.sum(array_s)/5)
# Out:
# 11.303999999999998
