# %%
import os

# %%
current_path = os.getcwd()
print(current_path)
# Out:
# /Users/tharhtetsan/Documents/GitHub/zero_2_hero_python/img_processing

# %%
os.listdir(current_path)
# Out:
# ['.DS_Store',
#  'Image processing  basic functions.ipynb',
#  '.ipynb_checkpoints',
#  'test_2.png',
#  'test_1.png']

# %%
image_name = "test_2.png"
image_path = current_path+"/"+image_name
print(image_path)
# Out:
# /Users/tharhtetsan/Documents/GitHub/zero_2_hero_python/img_processing/test_2.png

# %% [markdown]
# #### Opencv Read image

# %%
import cv2
import matplotlib.pyplot as plt

bgr_image = cv2.imread(image_path)
#(blue,green,red)

# %%
print(bgr_image.shape)
plt.imshow(bgr_image)
# Out:
# (516, 368, 3)

# %%
rgb_image = cv2.cvtColor(bgr_image,cv2.COLOR_BGR2RGB)
print(rgb_image.shape)
plt.imshow(rgb_image)
# Out:
# (516, 368, 3)

# %% [markdown]
# #### Pillow read image

# %%
from PIL import Image
image = Image.open(image_path)
plt.imshow(image)

# %%
red_channel = rgb_image[:,:,0]
green_channel = rgb_image[:,:,1]
blue_channel = rgb_image[:,:,2]
print(red_channel.shape)
plt.imshow(red_channel)
# Out:
# (516, 368)

# %%
plt.imshow(green_channel)

# %%
plt.imshow(blue_channel)
